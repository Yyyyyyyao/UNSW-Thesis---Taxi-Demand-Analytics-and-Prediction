# %%
import pandas as pd
from sklearn.metrics import mean_squared_error
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split
import statistics

# %%
new_df = pd.read_csv('xg_2017_01_final.csv')

#X, y = new_df.iloc[:, :-1], new_df.iloc[:, -1]

X, y = new_df.iloc[:, :-1], new_df.loc[:, ['PULocationID', 'count']]


#data_dmatrix = xgb.DMatrix(data=X,label=y)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 123)

xg_reg = xgb.XGBRegressor(objective='reg:linear', colsample_bytree = 0.9, subsample= 0.96, min_child_weight = 6.19, learning_rate = 0.1186, max_depth=14, gamma=1, n_estimators = 463)

xg_reg.fit(X_train,y_train)
preds = xg_reg.predict(X_test)

rmse = np.sqrt(mean_squared_error(y_test[:,-1], preds[:,-1]))
print("RMSE: %f" % (rmse))


testacc = statistics.mean(abs(y_test[:,-1] - preds[:,-1]))
print('Test acc: %.2f acc' % (testacc))



'''
df_monday = pd.read_csv('Monday_eval_dataset.csv')
X_mon_test, y_mon_test = df_monday.iloc[:, :-1], df_monday.iloc[:, -1]
mon_preds = xg_reg.predict(X_mon_test)
mon_mean = statistics.mean(abs(mon_preds - y_mon_test))
print(mon_preds)
print('Test acc: %.2f acc' % (mon_mean))
'''
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-62bc9ab30e5e> in <module>
#      12 xg_reg = xgb.XGBRegressor(objective='reg:linear', colsample_bytree = 0.9, subsample= 0.96, min_child_weight = 6.19, learning_rate = 0.1186, max_depth=14, gamma=1, n_estimators = 463)
#      13
# ---> 14 xg_reg.fit(X_train,y_train)
#      15 preds = xg_reg.predict(X_test)
#      16
#
# /usr/local/lib/python3.7/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, callbacks)
#     358                                    missing=self.missing, nthread=self.n_jobs)
#     359         else:
# --> 360             trainDmatrix = DMatrix(X, label=y, missing=self.missing, nthread=self.n_jobs)
#     361
#     362         evals_result = {}
#
# /usr/local/lib/python3.7/site-packages/xgboost/core.py in __init__(self, data, label, missing, weight, silent, feature_names, feature_types, nthread)
#     383                                                             feature_names,
#     384                                                             feature_types)
# --> 385         label = _maybe_pandas_label(label)
#     386         label = _maybe_dt_array(label)
#     387         weight = _maybe_dt_array(weight)
#
# /usr/local/lib/python3.7/site-packages/xgboost/core.py in _maybe_pandas_label(label)
#     261     if isinstance(label, DataFrame):
#     262         if len(label.columns) > 1:
# --> 263             raise ValueError('DataFrame for label cannot have multiple columns')
#     264
#     265         label_dtypes = label.dtypes
#
# ValueError: DataFrame for label cannot have multiple columns

# %%
params = {"objective":"reg:linear",'colsample_bytree': 0.3,'learning_rate': 0.1,
                'max_depth': 5, 'alpha': 10}
cv_results = xgb.cv(dtrain=data_dmatrix, params=params, nfold=3,
                    num_boost_round=50,early_stopping_rounds=10,metrics="rmse", as_pandas=True, seed=123)
cv_results.head()
# Out:
# [15:45:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
# [15:45:56] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.
#    train-rmse-mean  train-rmse-std  test-rmse-mean  test-rmse-std
# 0       200.992823        0.341767      201.004023       0.668967
# 1       194.119716        2.414950      194.179947       1.744794
# 2       188.718333        4.223449      188.799800       3.569454
# 3       185.315659        4.143771      185.405563       3.450336
# 4       181.305756        6.153281      181.416789       5.436886

# %%
xg_reg = xgb.train(params=params, dtrain=data_dmatrix, num_boost_round=10)
# Out:
# [15:48:06] WARNING: src/objective/regression_obj.cu:152: reg:linear is now deprecated in favor of reg:squarederror.

# %%
import matplotlib.pyplot as plt

xgb.plot_tree(xg_reg,num_trees=0)
plt.rcParams['figure.figsize'] = [50, 50]
plt.show()

# %%
import matplotlib.pyplot as plt
xgb.plot_importance(xg_reg)
plt.rcParams['figure.figsize'] = [50, 10]
plt.show()
