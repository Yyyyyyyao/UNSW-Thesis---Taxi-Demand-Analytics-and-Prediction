# %%
import pandas as pd
import numpy as np

# %%
dateparse = lambda x: pd.datetime.strptime(x, '%Y-%m-%d')
new_df = pd.read_csv('xg_2017_01_withAllTime.csv', parse_dates=['Date'], date_parser=dateparse)

# %%
new_df['dayofweek'] = new_df['Date'].dt.weekday

# %%
new_df.to_csv('xg_2017_01_final.csv', index=False)

# %%
new_df
# Out:
#        PULocationID       Date  Hours  time1  time2  time3  count  dayofweek
# 0                 1 2017-01-01      3      0      0      0      1          6
# 1                 1 2017-01-01      4      0      0      1      1          6
# 2                 1 2017-01-01      5      0      1      1      2          6
# 3                 1 2017-01-01      6      1      1      2      2          6
# 4                 1 2017-01-01      7      1      2      2      2          6
# ...             ...        ...    ...    ...    ...    ...    ...        ...
# 89509           265 2017-01-31     19      4      4      6     12          1
# 89510           265 2017-01-31     20      4      6     12      8          1
# 89511           265 2017-01-31     21      6     12      8      8          1
# 89512           265 2017-01-31     22     12      8      8      8          1
# 89513           265 2017-01-31     23      8      8      8     13          1
#
# [89514 rows x 8 columns]

# %%
del new_df['Date']

# %%
cols = new_df.columns.tolist()

# %%
cols
# Out:
# ['PULocationID', 'Hours', 'time1', 'time2', 'time3', 'count', 'dayofweek']

# %%
cols = cols[-1:] + cols[:-1]

# %%
new_df = new_df[cols]

# %%
new_df
# Out:
#        dayofweek  PULocationID  Hours  time1  time2  time3  count
# 0              6             1      3      0      0      0      1
# 1              6             1      4      0      0      1      1
# 2              6             1      5      0      1      1      2
# 3              6             1      6      1      1      2      2
# 4              6             1      7      1      2      2      2
# ...          ...           ...    ...    ...    ...    ...    ...
# 89509          1           265     19      4      4      6     12
# 89510          1           265     20      4      6     12      8
# 89511          1           265     21      6     12      8      8
# 89512          1           265     22     12      8      8      8
# 89513          1           265     23      8      8      8     13
#
# [89514 rows x 7 columns]

# %%
new_df.to_csv('xg_2017_01_final.csv', index=False)

# %%
cols = new_df.columns.tolist()
cols
# Out:
# ['dayofweek', 'PULocationID', 'Hours', 'time1', 'time2', 'time3', 'count']

# %%
cols = ['dayofweek', 'Hours', 'time1', 'time2', 'time3', 'PULocationID', 'count']

# %%
new_df = new_df[cols]

# %%
new_df.to_csv('xg_2017_01_final.csv', index=False)

# %%
X, y = new_df.iloc[:, :-1], new_df.iloc[:, -1]

# %%
a = new_df.loc[:, ['PULocationID', 'count']]
a.shape
# Out:
# (89514, 2)

# %%
a.reshape(179028,1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-8951b2181c33> in <module>
# ----> 1 a.reshape(179028,1)
#
# /usr/local/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5178             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5179                 return self[name]
# -> 5180             return object.__getattribute__(self, name)
#    5181
#    5182     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'
